# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Movie Recommender System**

# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('/content/drive/MyDrive/FML 3rd Year EE/Project/tmdb_5000_movies.csv')
credits = pd.read_csv('/content/drive/MyDrive/FML 3rd Year EE/Project/tmdb_5000_credits.csv')

# %%
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
credits.rename(columns = {"movie_id": "id"}, inplace = True)
credits = credits.drop(['title'], axis=1)
credits.head(3)
# Out:
#        id                                               cast  \
# 0   19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1     285  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  206647  [{"cast_id": 1, "character": "James Bond", "cr...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...

# %%
movies = movies.merge(credits, on='id')
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# Filtering out important features:
# 1. genres
# 2. id
# 3. keywords
# 4. overview
# 5. vote_average
# 6. cast
# 7. crew

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'cast', 'crew'],
#       dtype='object')

# %%
movies = movies[['id', 'title', 'overview', 'genres', 'keywords', 'vote_average', 'cast', 'crew']]
movies
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# ...

# %%
movies.isnull().sum()   # check if any entry is null
# Out:
# id              0
# title           0
# overview        3
# genres          0
# keywords        0
# vote_average    0
# cast            0
# crew            0
# dtype: int64

# %%
movies.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
movies.duplicated().sum()   #check if any duplicate exists
# Out:
# 0

# %%
movies.shape
# Out:
# (4800, 8)

# %% [markdown]
# **Data Preprocessing:**

# %%
# Preprocessing functions:

# for genres and keywords:
import ast
def extractGenres(allGenres):
  allGenres = ast.literal_eval(allGenres)   # converts string of lists into list
  result = []

  for genre in allGenres:
    result.append(genre['name'])

  return result

# for top 3 casts:
def getTopThreeCasts(allCasts):
  allCasts = ast.literal_eval(allCasts)
  result = []

  count = 0
  for cast in allCasts:
    if count == 3: break
    result.append(cast['name'])
    count += 1

  return result

# for Director from Crew:
def getDirector(allCrew):
  allCrew = ast.literal_eval(allCrew)
  result = []

  for crew in allCrew:
    if crew['job'].lower() == 'director':
      result.append(crew['name'])
      break

  return result

# %%
movies['genres'] = movies['genres'].apply(extractGenres)
movies['keywords'] = movies['keywords'].apply(extractGenres)
movies['cast'] = movies['cast'].apply(getTopThreeCasts)
movies['crew'] = movies['crew'].apply(getDirector)
movies['description'] = movies['overview']
movies['overview'] = movies['overview'].apply(lambda x:x.split()) # converting overview into list so as to concatinate
# Out:
# <ipython-input-14-04033a7fa25c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['genres'] = movies['genres'].apply(extractGenres)
# <ipython-input-14-04033a7fa25c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['keywords'] = movies['keywords'].apply(extractGenres)
# <ipython-input-14-04033a7fa25c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
movies.head(3)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
#
#                                             keywords  vote_average  \
# 0  [culture clash, future, space war, space colon...           7.2
# 1  [ocean, drug abuse, exotic island, east india ...           6.9
# 2  [spy, based on novel, secret agent, sequel, mi...           6.3
#
# ...

# %% [markdown]
# Removing spaces from tags

# %%
movies['genres'] = movies['genres'].apply(lambda x: [i.replace(" ", "") for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x: [i.replace(" ", "") for i in x])
movies['cast'] = movies['cast'].apply(lambda x: [i.replace(" ", "") for i in x])
movies['crew'] = movies['crew'].apply(lambda x: [i.replace(" ", "") for i in x])
# Out:
# <ipython-input-16-2d340bd78443>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['genres'] = movies['genres'].apply(lambda x: [i.replace(" ", "") for i in x])
# <ipython-input-16-2d340bd78443>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['keywords'] = movies['keywords'].apply(lambda x: [i.replace(" ", "") for i in x])
# <ipython-input-16-2d340bd78443>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
movies.head(3)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
#
#                                             keywords  vote_average  \
# 0  [cultureclash, future, spacewar, spacecolony, ...           7.2
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...           6.9
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...           6.3
#
# ...

# %% [markdown]
# Making final Tag for word vectors:

# %%
movies['tags'] =  movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] +  movies['crew']
# Out:
# <ipython-input-18-1c5317d31daf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags'] =  movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] +  movies['crew']

# %% [markdown]
# **Final DataFrame:**

# %%
newDf = movies[['id', 'title', 'tags', 'vote_average', 'description']]
newDf
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                    tags  vote_average  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...           7.2
# 1     [Captain, Barbossa,, long, believed, to, be, d...           6.9
# 2     [A, cryptic, message, from, Bond’s, past, send...           6.3
# ...

# %%
newDf.shape
# Out:
# (4800, 5)

# %%
# convert tags list into string:
newDf.dtypes
newDf['tags'] = newDf['tags'].apply(lambda x: " ".join(x))
newDf['tags'] = newDf['tags'].apply(lambda x: x.lower())
newDf.head(2)
# Out:
# <ipython-input-21-a7afd86fcdb1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDf['tags'] = newDf['tags'].apply(lambda x: " ".join(x))
# <ipython-input-21-a7afd86fcdb1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDf['tags'] = newDf['tags'].apply(lambda x: x.lower())
#       id                                     title  \
# 0  19995                                    Avatar
# 1    285  Pirates of the Caribbean: At World's End
#
# ...

# %%
newDf['tags'][0]
# Out:
# 'in the 22nd century, a paraplegic marine is dispatched to the moon pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. action adventure fantasy sciencefiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d samworthington zoesaldana sigourneyweaver jamescameron'

# %% [markdown]
# **Stemming:**

# %%
# derives all the root words of a given text:
# stem('loving loved loves') = love ---> so as to avoid extra vectors
import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    result = []
    for i in text.split():
        result.append(ps.stem(i))

    return " ".join(result)

# %%
newDf['tags'] = newDf['tags'].apply(stem)
# Out:
# <ipython-input-25-885c71d41175>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDf['tags'] = newDf['tags'].apply(stem)

# %% [markdown]
# **Vectorization**

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 5000, stop_words = 'english')

# %%
vectors = cv.fit_transform(newDf['tags']).toarray()  #converts scipy array to numpy array
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
cv.get_feature_names()  #all freq 5000 words
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['000',
#  '007',
#  '10',
#  '100',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '17th',
#  '18',
#  '18th',
#  '18thcenturi',
#  '19',
#  '1910',
#  '1920',
#  '1930',
#  '1940',
#  '1944',
#  '1950',
#  '1950s',
#  '1960',
#  '1960s',
#  '1970',
#  '1970s',
#  '1971',
#  '1974',
#  '1976',
#  '1980',
#  '1985',
#  '1990',
#  '1999',
#  '19th',
#  '19thcenturi',
#  '20',
#  '200',
#  '2003',
#  '2009',
#  '20th',
#  '21st',
#  '23',
#  '24',
#  '25',
#  '30',
#  '300',
#  '3d',
#  '40',
#  '50',
#  '500',
#  '60',
#  '70',
#  '80',
#  'aaron',
#  'aaroneckhart',
#  'abandon',
#  'abduct',
#  'abigailbreslin',
#  'abil',
#  'abl',
#  'aboard',
#  'abov',
#  'abus',
#  'academ',
# ...

# %%
newDf
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                    tags  vote_average  \
# 0     in the 22nd century, a parapleg marin is dispa...           7.2
# 1     captain barbossa, long believ to be dead, ha c...           6.9
# 2     a cryptic messag from bond’ past send him on a...           6.3
# ...

# %% [markdown]
# **Cosine Similarity**

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vectors)

similarity[0]   # tell similarity of this movie wrt other movies
# Out:
# array([1.        , 0.08346223, 0.0860309 , ..., 0.04499213, 0.        ,
#        0.        ])

# %% [markdown]
# **Recommender**

# %%
# enumerate creates a indexing to each element present in similarity
def recommendMovies(movie):

  isPresent = movie in newDf['title'].values
  if isPresent == False:
    print("Sorry. This movie is not present in our database.")
    return

  id = newDf[newDf['title'] == movie].index[0]
  similarityScores = similarity[id]

  # map actual index and sort DESC on the basis of second element i.e. score
  result = sorted(list(enumerate(similarityScores)), reverse = True, key = lambda x: x[1])[1:6]

  for i in result:
    # i[0] is the id of present movie, get title from that
    print("Movie: ", newDf.iloc[i[0]].title)
    print("Overview: ", newDf.iloc[i[0]].description)
    print("Votes: ", newDf.iloc[i[0]].vote_average, end="\n\n")

# %%
recommendMovies('Avatar')
# Out:
# Movie:  Aliens vs Predator: Requiem
# Overview:  A sequel to 2004's Alien vs. Predator, the iconic creatures from two of the scariest film franchises in movie history wage their most brutal battle ever - in our own backyard. The small town of Gunnison, Colorado becomes a war zone between two of the deadliest extra-terrestrial life forms - the Alien and the Predator. When a Predator scout ship crash-lands in the hills outside the town, Alien Facehuggers and a hybrid Alien/Predator are released and begin to terrorize the town.
# Votes:  4.9
#
# Movie:  Aliens
# Overview:  When Ripley's lifepod is found by a salvage crew over 50 years later, she finds that terra-formers are on the very planet they found the alien species. When the company sends a family of colonists out to investigate her story, all contact is lost with the planet and colonists. They enlist Ripley and the colonial marines to return and search for answers.
# Votes:  7.7
#
# Movie:  Falcon Rising
# ...

# %%
recommendMovies('Ba')
# Out:
# Sorry. This movie is not present in our database.

# %% [markdown]
# **System**

# %%
import pickle
pickle.dump(newDf.to_dict(), open('moviesDict.pkl', 'wb'))
pickle.dump(similarity, open('similarity.pkl', 'wb'))
